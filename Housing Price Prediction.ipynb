# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
housing_price = pd.read_csv('kc_house_data.csv')

# %%
housing_price.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
housing_price.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
housing_price.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
housing_price.shape
# Out:
# (21613, 21)

# %%
housing_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
sns.heatmap(housing_price.corr())
plt.title('Correlation Plot')
plt.show()

# %%
housing_price['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
housing_price['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
data = housing_price.floors.value_counts()
count  = housing_price['floors'].value_counts()
plt.figure(figsize=(10,15))
data.plot.pie( title = 'Pie Chart Showing floors Distribution')
plt.show()

# %%
#Plotting the distribution of the Furnishing Status
floors_count  = housing_price['floors'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x= floors_count.values, y = floors_count.index,   alpha=1, orient = 'h',palette='Paired')
plt.title('Distribution of floors in the Dataset ')
plt.ylabel('Floors', fontsize=12)
plt.xlabel('No. of House', fontsize=12)
plt.show()

# %%
housing_price.plot(kind='scatter', x = 'sqft_living', y = 'price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
#clean dataset if necessary
housing_price.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
housing_price.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
housing_price['sqft_living15']
# Out:
# 0        1340
# 1        1690
# 2        2720
# 3        1360
# 4        1800
#          ...
# 21608    1530
# 21609    1830
# 21610    1020
# 21611    1410
# 21612    1020
# Name: sqft_living15, Length: 21613, dtype: int64

# %%
housing_price=housing_price.drop(['id','date','yr_renovated','yr_renovated','lat','long'],axis=1)

# %%
housing_price.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  zipcode  \
# 0     0          3      7        1180              0      1955    98178
# 1     0          3      7        2170            400      1951    98125
# 2     0          3      6         770              0      1933    98028
# 3     0          5      7        1050            910      1965    98136
# 4     0          3      8        1680              0      1987    98074
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# ...

# %%
#Splitting the dataset into features and targets
X = housing_price.drop(['price'], axis = 1)
y = housing_price['price']

# %%
print(X)
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
print(y)
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state=2)

# %%
#from sklearn.preprocessing import StandardScaler

#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

#Loading the Linear Regression Model
LR = LinearRegression()

LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Model Evaluation
#Let's test our model on our training data
y_pred = LR.predict(X_test)

# %%
y_pred_df = pd.DataFrame(y_pred, columns = ['Predicted Price'])

# %%
X_test_df=pd.DataFrame(X_test)

# %%
prediction= pd.concat([X_test_df.reset_index(drop=True), y_test.reset_index(drop=True), y_pred_df.reset_index(drop=True)], axis=1)

# %%
prediction
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            4       2.25         2410      4250     1.5           0     0
# 1            3       1.50         2170     16600     1.0           1     2
# 2            2       1.00         1450      6380     1.0           0     0
# 3            5       3.25         4500      9648     2.0           0     4
# 4            2       1.00          860      6000     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 6479         3       1.50         1550     40752     1.0           0     0
# 6480         4       2.50         3160     13194     2.0           0     0
# 6481         4       2.50         2370     10631     2.0           0     0
# 6482         3       2.25         1350       980     2.0           0     0
# 6483         4       1.75         2120      4000     1.5           0     0
#
# ...

# %%
coefficients = LR.coef_
print(f'Coefficients {coefficients}')
# Out:
# Coefficients [ 2.33619259e+02  7.07225089e+04  9.66654305e+05  4.31441109e+05
#   3.19455190e+05  3.48490707e+05  3.92719633e+05  8.27971841e+05
#   9.30041162e+05  2.86048480e+05  6.59642211e+05  2.03923963e+05
#   9.66778779e+04 -3.00601841e+05]

# %%
intercept = LR.intercept_
print(f'Intercept: {intercept}')
# Out:
# Intercept: 150990.69694485422

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f'R2: {r2}')
# Out:
# R2: 0.653543370688221

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse}')
# Out:
# MSE: 1273374898779.1765

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f'RMSE: {rmse}')
# Out:
# RMSE: 1128439.142700738

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print(f'MAE {mae}')
# Out:
# MAE 831635.0030526068
